# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score 
from sklearn.metrics import ConfusionMatrixDisplay

# %%
matches = pd.read_csv('../data/processed/features_v2.csv')

# %%
matches['GoalDiffLast5'] = matches['HomeGoalsLast5'] - matches['AwayGoalsLast5'] 
matches['PointsDiffLast5'] = matches['HomePointsLast5'] - matches['AwayPointsLast5'] 
matches['GoalAgainstDiffLast5'] = matches['AwayGoalsAgainstLast5'] - matches['HomeGoalsAgainstLast5'] 
matches['ShotDiffLast5'] = matches['HomeShotsForLast5'] - matches['AwayShotsForLast5'] 
matches['ShotOTDiffLast5'] = matches['HomeShotsOnTargetLast5'] - matches['AwayShotsOnTargetLast5']
# Out:
# C:\Users\harry\AppData\Local\Temp\ipykernel_42772\2143085457.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   matches['GoalDiffLast5'] = matches['HomeGoalsLast5'] - matches['AwayGoalsLast5']
# C:\Users\harry\AppData\Local\Temp\ipykernel_42772\2143085457.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   matches['PointsDiffLast5'] = matches['HomePointsLast5'] - matches['AwayPointsLast5']
# C:\Users\harry\AppData\Local\Temp\ipykernel_42772\2143085457.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   matches['GoalAgainstDiffLast5'] = matches['AwayGoalsAgainstLast5'] - matches['HomeGoalsAgainstLast5']
# C:\Users\harry\AppData\Local\Temp\ipykernel_42772\2143085457.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   matches['ShotDiffLast5'] = matches['HomeShotsForLast5'] - matches['AwayShotsForLast5']
# C:\Users\harry\AppData\Local\Temp\ipykernel_42772\2143085457.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   matches['ShotOTDiffLast5'] = matches['HomeShotsOnTargetLast5'] - matches['AwayShotsOnTargetLast5']

# %%
features = [ 'GoalDiffLast5', 'PointsDiffLast5', 'GoalAgainstDiffLast5', 'ShotOTDiffLast5', 'PPGDiff', 'GDPerGameDiff', 'GoalsPerGameDiff', 'GoalsAgainstPerGameDiff' ]

# %%
train = matches[matches['Season'] != '25-26'] 
test = matches[matches['Season'] == '25-26']

# %%
X_train = train[features] 
y_train = train['FTR'] 
X_test = test[features] 
y_test = test['FTR']

# %%
 
model = LogisticRegression(
    max_iter=1000,
)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
preds = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, preds) 
print(accuracy)
# Out:
# 0.4789473684210526

# %%
ConfusionMatrixDisplay.from_predictions(y_test, preds)

# %%
probs = model.predict_proba(X_test) 
print(model.classes_) 
print(probs[0])
# Out:
# ['A' 'D' 'H']
# [0.30253241 0.22716662 0.47030096]

# %%
results = test[['HomeTeam', 'AwayTeam', 'FTR']].copy() 
results['Predicted'] = preds 
results['AwayProb'] = probs[:, 0] 
results['DrawProb'] = probs[:, 1] 
results['HomeProb'] = probs[:, 2] 
results.head(10)
# Out:
#            HomeTeam        AwayTeam FTR Predicted  AwayProb  DrawProb  \
# 1520      Liverpool     Bournemouth   H         H  0.302532  0.227167
# 1521    Aston Villa       Newcastle   D         H  0.341900  0.306085
# 1522       Brighton          Fulham   D         H  0.264795  0.225861
# 1523     Sunderland        West Ham   H         H  0.331330  0.258530
# 1524      Tottenham         Burnley   H         A  0.376740  0.327861
# 1525         Wolves        Man City   A         H  0.343785  0.248480
# 1526        Chelsea  Crystal Palace   D         H  0.316819  0.292622
# 1527  Nott'm Forest       Brentford   H         H  0.318532  0.252264
# 1528     Man United         Arsenal   A         H  0.309474  0.241023
# 1529          Leeds         Everton   H         A  0.380614  0.286155
#
#       HomeProb
# 1520  0.470301
# 1521  0.352015
# 1522  0.509343
# 1523  0.410140
# 1524  0.295399
# 1525  0.407735
# 1526  0.390558
# 1527  0.429203
# 1528  0.449503
# 1529  0.333231

# %%
importance = pd.Series( model.coef_[2], index=features ).sort_values(ascending=False) 
print(importance)
# Out:
# PPGDiff                    0.292202
# GoalAgainstDiffLast5       0.150430
# ShotOTDiffLast5            0.108456
# GDPerGameDiff              0.070861
# GoalsAgainstPerGameDiff    0.039956
# GoalsPerGameDiff           0.030906
# GoalDiffLast5             -0.010053
# PointsDiffLast5           -0.016718
# dtype: float64

# %%
from sklearn.metrics import log_loss 
print(log_loss(y_test, probs))
# Out:
# 1.0492356340651103

# %%
probs = model.predict_proba(X_test) 
results['DrawProb'] = probs[:, list(model.classes_).index('D')] 
results.sort_values('DrawProb', ascending=False).head(20)
# Out:
#             HomeTeam        AwayTeam FTR Predicted  AwayProb  DrawProb  \
# 1524       Tottenham         Burnley   H         A  0.376740  0.327861
# 1763     Bournemouth     Aston Villa   D         A  0.427664  0.323235
# 1521     Aston Villa       Newcastle   D         H  0.341900  0.306085
# 1828       Tottenham   Nott'm Forest   A         H  0.323909  0.300340
# 1532     Bournemouth          Wolves   H         H  0.166514  0.299879
# 1867         Chelsea   Nott'm Forest   A         H  0.307828  0.299879
# 1856          Wolves       Tottenham   A         A  0.446050  0.299431
# 1720        West Ham   Nott'm Forest   A         A  0.381586  0.299216
# 1644       Tottenham          Fulham   A         H  0.274524  0.298251
# 1876  Crystal Palace         Everton   D         A  0.358224  0.297748
# 1559        Man City      Man United   H         H  0.336203  0.296914
# 1843         Chelsea      Man United   A         A  0.385020  0.296269
# 1850     Bournemouth           Leeds   D         H  0.300427  0.294813
# 1551     Bournemouth        Brighton   H         H  0.266195  0.293012
# 1545           Leeds       Newcastle   D         A  0.383863  0.292899
# 1526         Chelsea  Crystal Palace   D         H  0.316819  0.292622
# 1592         Burnley           Leeds   H         A  0.437707  0.290413
# 1685       Tottenham       Liverpool   A         A  0.374990  0.290242
# 1620       Tottenham      Man United   D         H  0.313670  0.290238
# 1831       Brentford         Everton   D         H  0.330318  0.289378
#
#       HomeProb
# 1524  0.295399
# 1763  0.249101
# 1521  0.352015
# 1828  0.375751
# 1532  0.533607
# 1867  0.392293
# 1856  0.254519
# 1720  0.319198
# 1644  0.427225
# 1876  0.344028
# 1559  0.366883
# 1843  0.318711
# 1850  0.404759
# 1551  0.440793
# 1545  0.323237
# 1526  0.390558
# 1592  0.271880
# 1685  0.334768
# 1620  0.396091
# 1831  0.380305
